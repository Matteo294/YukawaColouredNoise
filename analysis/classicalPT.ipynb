# %%
import numpy as np
from matplotlib import pyplot as plt 
from pandas import read_csv
import sys
import os
from matplotlib import rcParams
import toml

# %load_ext autoreload
# %autoreload 2

from correlations import *
from read_in_data import *
from mass_fit import *
from mass_matteo import *
from functions import *

# %%
param = ("physics", "cutFraction")
simulations = []
for i in range(1, 61):
    dataset = Dataset(64, 64)
    dataset.add_data("./data/classicalPT/classicaltoquantum/conf" + str(i) + "/", param, 1)
    simulations.append(dataset)
    #print(dataset.toml_params[param[0]][param[1]], dataset.toml_params["fermions"]["fermion_mass"])

# %%
for i in range(61, 71):
    dataset = Dataset(64, 64)
    dataset.add_data("./data/classicalPT/classicaltoquantum/conf" + str(i) + "/", param, 1)
    simulations.append(dataset)

# %% [markdown]
# # Magnetisation

# %%
data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.04:
        val, err = s.compute_mag()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 4 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.03:
        val, err = s.compute_mag()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 3 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.02:
        val, err = s.compute_mag()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 2 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.01:
        val, err = s.compute_mag()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.005:
        val, err = s.compute_mag()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 5 \cdot 10^{-3}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.001:
        val, err = s.compute_mag()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 10^{-3}$")

plt.legend(fontsize=10)
plt.xlabel(r"$s$", fontsize = 16)
plt.ylabel(r"$\left\langle |\phi| \right\rangle$", fontsize=16)
plt.grid()
plt.tight_layout()
plt.savefig("magnetisation.pdf")

# %% [markdown]
# # Condensate

# %%
data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.04:
        val, err = s.compute_condensate()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 4 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.03:
        val, err = s.compute_condensate()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 3 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.02:
        val, err = s.compute_condensate()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 2 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.01:
        val, err = s.compute_condensate()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.005:
        val, err = s.compute_condensate()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 5 \cdot 10^{-3}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.001:
        val, err = s.compute_condensate()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, errs, fmt='o--', markersize=4, label=r"$m_{q} = 10^{-3}$")

plt.legend(fontsize=10)
plt.grid()
plt.xlabel(r"$s$", fontsize = 16)
plt.ylabel(r"$\left\langle \bar\psi \psi \right\rangle$", fontsize=16)
plt.tight_layout()
plt.savefig("condensate.pdf")

# %% [markdown]
# # Fermion Mass

# %%
data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.04:
        val, err = s.compute_mqphys(filtering=True)
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 4 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.03:
        val, err = s.compute_mqphys(filtering=True)
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 3 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.02:
        val, err = s.compute_mqphys(filtering=True)
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 2 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.01:
        val, err = s.compute_mqphys(filtering=True)
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.005:
        val, err = s.compute_mqphys(filtering=True)
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 5 \cdot 10^{-3}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.001:
        val, err = s.compute_mqphys(filtering=True)
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)    
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 10^{-3}$")

plt.legend(fontsize=10)
plt.grid()
plt.xlabel(r"$s$", fontsize = 16)
plt.ylabel(r"$m_{q,phys}$", fontsize=16)
plt.tight_layout()
plt.savefig("mqphys.pdf")

# %%
data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.04:
        val, err = s.compute_susceptibility()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 4 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.03:
        val, err = s.compute_susceptibility()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 3 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.02:
        val, err = s.compute_susceptibility()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 2 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.01:
        val, err = s.compute_susceptibility()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.005:
        val, err = s.compute_susceptibility()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 5 \cdot 10^{-3}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.001:
        val, err = s.compute_susceptibility()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 5 \cdot 10^{-3}$")


data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.001:
        val, err = s.compute_susceptibility()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
 

plt.legend(fontsize=10)
plt.grid()
plt.xlabel(r"$s$", fontsize = 16)
plt.ylabel(r"$\chi^2$", fontsize=16)
plt.tight_layout()
plt.savefig("susceptiblity.pdf")

# %%
data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.04:
        val, err = s.compute_binder_cumulant()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 4 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.03:
        val, err = s.compute_binder_cumulant()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 3 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.02:
        val, err = s.compute_binder_cumulant()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 2 \cdot 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.01:
        val, err = s.compute_binder_cumulant()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 10^{-2}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.005:
        val, err = s.compute_binder_cumulant()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 5 \cdot 10^{-3}$")

data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.001:
        val, err = s.compute_binder_cumulant()
        data.append((s.toml_params[param[0]][param[1]], val, err))
        params, vals, errs = sort_data(data)
plt.errorbar([m2 for m2 in params], vals, [0 for _ in errs], fmt='o--', markersize=4, label=r"$m_{q} = 10^{-3}$")
 
plt.legend(fontsize=10)
plt.grid()
plt.xlabel(r"$s$", fontsize = 16)
plt.ylabel(r"$U_L$", fontsize=16)
plt.tight_layout()
plt.savefig("binder.pdf")

# %%
# s = 1.0
data = []
for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.001 and (s.toml_params["physics"]["cutFraction"] > 0.99):
        val, err = get_fermionic_correlator(s.Sq_t)
        plt.errorbar(range(len(val)), val, err)
data = []
'''for s in simulations:
    if s.toml_params["fermions"]["fermion_mass"] == 0.001 and (s.toml_params["physics"]["cutFraction"] == 1.0):
        val, err = get_fermionic_correlator(s.Sq_t)
        plt.errorbar(range(len(val)), val, err)
#plt.errorbar([m2 for m2 in params], vals, errs, fmt='^-', markersize=7, label="s=1")'''
plt.legend()
plt.grid()
#plt.xlim([10,20])
plt.xlabel(r"$g$")
plt.ylabel(r"$\left\langle |\phi| \right\rangle$")
plt.tight_layout()
plt.savefig("magnetisation.pdf")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
